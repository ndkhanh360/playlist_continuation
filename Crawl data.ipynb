# %%
import os

# %%
os.environ['SPOTIPY_CLIENT_ID']="3e3851d02b36446a85fec637a37c573f"
os.environ['SPOTIPY_CLIENT_SECRET']="9c763e54e63744a190c9085f64779680"

# %% [markdown]
# # Crawl playlist data

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

auth_manager = SpotifyClientCredentials()
sp = spotipy.Spotify(auth_manager=auth_manager)

# %%
user = 'spotify'

# %%
playlists = sp.user_playlists(user)

# %%
playlists.keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
playlists['items'][0]
# Out:
# {'collaborative': False,
#  'description': 'Dua Lipa & DaBaby are on top of the Hottest 50!',
#  'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DXcBWIGoYBM5M'},
#  'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXcBWIGoYBM5M',
#  'id': '37i9dQZF1DXcBWIGoYBM5M',
#  'images': [{'height': None,
#    'url': 'https://i.scdn.co/image/ab67706f00000003fe7551807b99591f73c4fe6c',
#    'width': None}],
#  'name': "Today's Top Hits",
#  'owner': {'display_name': 'Spotify',
#   'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#   'href': 'https://api.spotify.com/v1/users/spotify',
#   'id': 'spotify',
#   'type': 'user',
#   'uri': 'spotify:user:spotify'},
#  'primary_color': None,
#  'public': True,
#  'snapshot_id': 'MTYwNzk2NjI4NiwwMDAwMDQ2MzAwMDAwMTc2NjI0MjY0NjUwMDAwMDE3NjRmODg4OWI1',
#  'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXcBWIGoYBM5M/tracks',
#   'total': 50},
#  'type': 'playlist',
# ...

# %%
tracks = sp.playlist_tracks('37i9dQZF1DXcBWIGoYBM5M')

# %%
tracks['items']
# Out:
# [{'added_at': '2020-12-14T17:18:06Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6M2wZ9GZgrQXHCFfjv46we'},
#       'href': 'https://api.spotify.com/v1/artists/6M2wZ9GZgrQXHCFfjv46we',
#       'id': '6M2wZ9GZgrQXHCFfjv46we',
#       'name': 'Dua Lipa',
#       'type': 'artist',
#       'uri': 'spotify:artist:6M2wZ9GZgrQXHCFfjv46we'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4r63FhuTkUYltbVAg5TQnk'},
#       'href': 'https://api.spotify.com/v1/artists/4r63FhuTkUYltbVAg5TQnk',
#       'id': '4r63FhuTkUYltbVAg5TQnk',
#       'name': 'DaBaby',
#       'type': 'artist',
#       'uri': 'spotify:artist:4r63FhuTkUYltbVAg5TQnk'}],
# ...

# %%
track_features = sp.track_features?
# Out:
# Object `sp.track_features` not found.

# %%
track_features = sp.audio_features(['463CkQjx2Zk1yXoBuierM9'])

# %%
track_features
# Out:
# [{'danceability': 0.702,
#   'energy': 0.825,
#   'key': 6,
#   'loudness': -3.787,
#   'mode': 0,
#   'speechiness': 0.0601,
#   'acousticness': 0.00883,
#   'instrumentalness': 0,
#   'liveness': 0.0674,
#   'valence': 0.915,
#   'tempo': 102.977,
#   'type': 'audio_features',
#   'id': '463CkQjx2Zk1yXoBuierM9',
#   'uri': 'spotify:track:463CkQjx2Zk1yXoBuierM9',
#   'track_href': 'https://api.spotify.com/v1/tracks/463CkQjx2Zk1yXoBuierM9',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/463CkQjx2Zk1yXoBuierM9',
#   'duration_ms': 203064,
#   'time_signature': 4}]

# %%
track_features = sp.audio_analysis('463CkQjx2Zk1yXoBuierM9')
